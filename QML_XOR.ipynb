# %%
import numpy as np
from qiskit import QuantumCircuit,transpile
from qiskit_aer import AerSimulator
# XOR dataset
X = np.array([[0,0],[0,1],[1,0],[1,1]])  
y = np.array([0,1,1,0])

# Parametrized ansatz + feature encoding
def build_circuit(x, params):
    """
    x: input array of 2 features [x1,x2]
    params: array of 4 parameters
    """
    qc = QuantumCircuit(2, 1) # Creates a quantum circuit with 2 qubits(qubit 0, qubit 1) and 1 classical bit(class level) for measurement.
    
    # Encode classical data using RX gates
    for i, val in enumerate(x):  #If a feature is 1, apply an X gate (NOT gate) to flip the qubit.This encodes the classical input into the quantum state.
        if val == 1:
            qc.x(i)
    
    # Ansatz (trainable rotations)
    qc.ry(params[0], 0) #RY(theta) → rotation around Y-axis by theta. These are trainable parameters.
    qc.ry(params[1], 1)
    qc.cx(0,1)          #CX(0,1) → CNOT gate entangles the qubits.
    qc.ry(params[2], 0)  #The second pair of RY gates allows the circuit to adjust its output based on the entanglement.
    qc.ry(params[3], 1)
    
    # Measure qubit 1 (output qubit)
    qc.measure(1,0)   #Measures qubit 1 and stores the result in classical bit 0.  
                      #This is the “output” qubit, whose probability of being 1 will be used as the prediction
    return qc

#Backend
shots = 1024                  # the number of times the circuit is executed.
simulator = AerSimulator()    # simulates the quantum circuit on a classical computer.

#Dummy optimizer loop
params = np.random.rand(4)  # params → initial random parameters  ,4 random parameters for the RY gates.
learning_rate = 0.1  # learning_rate → controls how much we update the parameters each step.

for epoch in range(100):
    print(f"Epoch {epoch+1}")
    for xi, yi in zip(X, y):
        qc = build_circuit(xi, params)  #Build the quantum circuit with build_circuit(xi, params).
        qc_t = transpile(qc,simulator)  #Transpile it for optimization (qc_t = transpile(...)).
        job = simulator.run(qc_t, backend=simulator, shots=shots) # Run the circuit on the simulator
        result = job.result()
        counts = result.get_counts() #Get the measurement counts (counts dictionary, e.g., {'0': 600, '1': 424}).
        
        # Compute probability of measuring '1'
        p1 = counts.get('1', 0)/shots   #counts.get('1', 0) → how many times qubit 1 was measured as 1.   Divide by shots → probability of output being 1.
        pred = p1  #This probability is treated as the prediction
        print(f"Input: {xi}, Label: {yi}, Pred: {pred:.2f}")
        
        # Dummy gradient step (not real gradient)
        params -= learning_rate * (pred - yi) * 0.01  # very simple update  #(pred - yi) → difference between predicted probability and true label.
    print("Params:", params)  # Multiply by learning_rate * 0.01 → very simple update to parameters.
# Out:
# Epoch 1
# Input: [0 0], Label: 0, Pred: 0.29
# Input: [0 1], Label: 1, Pred: 0.72
# Input: [1 0], Label: 1, Pred: 0.81
# Input: [1 1], Label: 0, Pred: 0.17
# Params: [0.34989997 0.98897381 0.09212578 0.14564073]
# Epoch 2
# Input: [0 0], Label: 0, Pred: 0.32
# Input: [0 1], Label: 1, Pred: 0.69
# Input: [1 0], Label: 1, Pred: 0.84
# Input: [1 1], Label: 0, Pred: 0.19
# Params: [0.34985896 0.9889328  0.09208477 0.14559972]
# Epoch 3
# Input: [0 0], Label: 0, Pred: 0.32
# Input: [0 1], Label: 1, Pred: 0.71
# Input: [1 0], Label: 1, Pred: 0.81
# Input: [1 1], Label: 0, Pred: 0.19
# Params: [0.34982576 0.9888996  0.09205157 0.14556651]
# Epoch 4
# Input: [0 0], Label: 0, Pred: 0.28
# Input: [0 1], Label: 1, Pred: 0.70
# Input: [1 0], Label: 1, Pred: 0.83
# Input: [1 1], Label: 0, Pred: 0.19
# Params: [0.34983943 0.98891327 0.09206524 0.14558019]
# Epoch 5
# Input: [0 0], Label: 0, Pred: 0.31
# Input: [0 1], Label: 1, Pred: 0.70
# Input: [1 0], Label: 1, Pred: 0.79
# Input: [1 1], Label: 0, Pred: 0.16
# Params: [0.34988435 0.98895819 0.09211016 0.14562511]
# Epoch 6
# Input: [0 0], Label: 0, Pred: 0.30
# Input: [0 1], Label: 1, Pred: 0.72
# Input: [1 0], Label: 1, Pred: 0.81
# Input: [1 1], Label: 0, Pred: 0.16
# Params: [0.34989802 0.98897186 0.09212383 0.14563878]
# Epoch 7
# Input: [0 0], Label: 0, Pred: 0.31
# Input: [0 1], Label: 1, Pred: 0.70
# Input: [1 0], Label: 1, Pred: 0.81
# Input: [1 1], Label: 0, Pred: 0.18
# Params: [0.34990876 0.9889826  0.09213457 0.14564952]
# Epoch 8
# Input: [0 0], Label: 0, Pred: 0.30
# Input: [0 1], Label: 1, Pred: 0.68
# Input: [1 0], Label: 1, Pred: 0.83
# Input: [1 1], Label: 0, Pred: 0.17
# Params: [0.34992829 0.98900213 0.0921541  0.14566905]
# Epoch 9
# Input: [0 0], Label: 0, Pred: 0.33
# Input: [0 1], Label: 1, Pred: 0.69
# Input: [1 0], Label: 1, Pred: 0.80
# Input: [1 1], Label: 0, Pred: 0.20
# Params: [0.34991072 0.98898456 0.09213653 0.14565148]
# Epoch 10
# Input: [0 0], Label: 0, Pred: 0.29
# Input: [0 1], Label: 1, Pred: 0.70
# Input: [1 0], Label: 1, Pred: 0.82
# Input: [1 1], Label: 0, Pred: 0.18
# Params: [0.34992341 0.98899725 0.09214922 0.14566417]
# Epoch 11
# Input: [0 0], Label: 0, Pred: 0.29
# Input: [0 1], Label: 1, Pred: 0.71
# Input: [1 0], Label: 1, Pred: 0.82
# Input: [1 1], Label: 0, Pred: 0.18
# Params: [0.34993025 0.98900409 0.09215606 0.14567101]
# Epoch 12
# Input: [0 0], Label: 0, Pred: 0.30
# Input: [0 1], Label: 1, Pred: 0.67
# Input: [1 0], Label: 1, Pred: 0.82
# Input: [1 1], Label: 0, Pred: 0.20
# Params: [0.34994197 0.98901581 0.09216778 0.14568273]
# Epoch 13
# Input: [0 0], Label: 0, Pred: 0.30
# Input: [0 1], Label: 1, Pred: 0.71
# Input: [1 0], Label: 1, Pred: 0.82
# Input: [1 1], Label: 0, Pred: 0.18
# Params: [0.34991755 0.98899139 0.09214336 0.14565831]
# Epoch 14
# Input: [0 0], Label: 0, Pred: 0.30
# Input: [0 1], Label: 1, Pred: 0.72
# Input: [1 0], Label: 1, Pred: 0.81
# Input: [1 1], Label: 0, Pred: 0.17
# Params: [0.34992048 0.98899432 0.09214629 0.14566124]
# Epoch 15
# Input: [0 0], Label: 0, Pred: 0.30
# Input: [0 1], Label: 1, Pred: 0.69
# Input: [1 0], Label: 1, Pred: 0.81
# Input: [1 1], Label: 0, Pred: 0.17
# Params: [0.34993904 0.98901288 0.09216485 0.1456798 ]
# Epoch 16
# Input: [0 0], Label: 0, Pred: 0.29
# Input: [0 1], Label: 1, Pred: 0.68
# Input: [1 0], Label: 1, Pred: 0.83
# Input: [1 1], Label: 0, Pred: 0.18
# Params: [0.34996443 0.98903827 0.09219024 0.14570519]
# Epoch 17
# Input: [0 0], Label: 0, Pred: 0.32
# Input: [0 1], Label: 1, Pred: 0.69
# Input: [1 0], Label: 1, Pred: 0.81
# Input: [1 1], Label: 0, Pred: 0.19
# Params: [0.3499449  0.98901874 0.09217071 0.14568565]
# Epoch 18
# Input: [0 0], Label: 0, Pred: 0.30
# Input: [0 1], Label: 1, Pred: 0.69
# Input: [1 0], Label: 1, Pred: 0.79
# Input: [1 1], Label: 0, Pred: 0.19
# Params: [0.34996443 0.98903827 0.09219024 0.14570519]
# Epoch 19
# Input: [0 0], Label: 0, Pred: 0.30
# Input: [0 1], Label: 1, Pred: 0.70
# Input: [1 0], Label: 1, Pred: 0.81
# Input: [1 1], Label: 0, Pred: 0.17
# Params: [0.34999079 0.98906463 0.0922166  0.14573155]
# Epoch 20
# Input: [0 0], Label: 0, Pred: 0.29
# Input: [0 1], Label: 1, Pred: 0.70
# Input: [1 0], Label: 1, Pred: 0.81
# Input: [1 1], Label: 0, Pred: 0.20
# Params: [0.34998982 0.98906366 0.09221563 0.14573058]
# Epoch 21
# Input: [0 0], Label: 0, Pred: 0.30
# Input: [0 1], Label: 1, Pred: 0.69
# Input: [1 0], Label: 1, Pred: 0.83
# Input: [1 1], Label: 0, Pred: 0.18
# Params: [0.34999763 0.98907147 0.09222344 0.14573839]
# Epoch 22
# Input: [0 0], Label: 0, Pred: 0.31
# Input: [0 1], Label: 1, Pred: 0.70
# Input: [1 0], Label: 1, Pred: 0.82
# Input: [1 1], Label: 0, Pred: 0.18
# Params: [0.34999177 0.98906561 0.09221758 0.14573253]
# Epoch 23
# Input: [0 0], Label: 0, Pred: 0.32
# Input: [0 1], Label: 1, Pred: 0.69
# Input: [1 0], Label: 1, Pred: 0.80
# Input: [1 1], Label: 0, Pred: 0.18
# Params: [0.35000447 0.98907831 0.09223028 0.14574523]
# Epoch 24
# Input: [0 0], Label: 0, Pred: 0.29
# Input: [0 1], Label: 1, Pred: 0.71
# Input: [1 0], Label: 1, Pred: 0.80
# Input: [1 1], Label: 0, Pred: 0.18
# Params: [0.35002302 0.98909686 0.09224883 0.14576378]
# Epoch 25
# Input: [0 0], Label: 0, Pred: 0.33
# Input: [0 1], Label: 1, Pred: 0.69
# Input: [1 0], Label: 1, Pred: 0.82
# Input: [1 1], Label: 0, Pred: 0.17
# Params: [0.3500113  0.98908514 0.09223711 0.14575206]
# Epoch 26
# Input: [0 0], Label: 0, Pred: 0.30
# Input: [0 1], Label: 1, Pred: 0.70
# Input: [1 0], Label: 1, Pred: 0.83
# Input: [1 1], Label: 0, Pred: 0.18
# Params: [0.34999958 0.98907342 0.09222539 0.14574034]
# Epoch 27
# Input: [0 0], Label: 0, Pred: 0.32
# Input: [0 1], Label: 1, Pred: 0.71
# Input: [1 0], Label: 1, Pred: 0.80
# Input: [1 1], Label: 0, Pred: 0.15
# Params: [0.35002204 0.98909588 0.09224785 0.1457628 ]
# Epoch 28
# Input: [0 0], Label: 0, Pred: 0.28
# Input: [0 1], Label: 1, Pred: 0.70
# Input: [1 0], Label: 1, Pred: 0.80
# Input: [1 1], Label: 0, Pred: 0.19
# Params: [0.35006306 0.9891369  0.09228887 0.14580382]
# Epoch 29
# Input: [0 0], Label: 0, Pred: 0.30
# Input: [0 1], Label: 1, Pred: 0.72
# Input: [1 0], Label: 1, Pred: 0.83
# Input: [1 1], Label: 0, Pred: 0.19
# Params: [0.35003376 0.9891076  0.09225957 0.14577452]
# Epoch 30
# Input: [0 0], Label: 0, Pred: 0.30
# Input: [0 1], Label: 1, Pred: 0.69
# Input: [1 0], Label: 1, Pred: 0.82
# Input: [1 1], Label: 0, Pred: 0.19
# Params: [0.35003865 0.98911249 0.09226446 0.1457794 ]
# Epoch 31
# Input: [0 0], Label: 0, Pred: 0.32
# Input: [0 1], Label: 1, Pred: 0.66
# Input: [1 0], Label: 1, Pred: 0.82
# Input: [1 1], Label: 0, Pred: 0.19
# Params: [0.35005329 0.98912713 0.0922791  0.14579405]
# Epoch 32
# Input: [0 0], Label: 0, Pred: 0.34
# Input: [0 1], Label: 1, Pred: 0.71
# Input: [1 0], Label: 1, Pred: 0.81
# Input: [1 1], Label: 0, Pred: 0.21
# Params: [0.34998982 0.98906366 0.09221563 0.14573058]
# Epoch 33
# Input: [0 0], Label: 0, Pred: 0.29
# Input: [0 1], Label: 1, Pred: 0.68
# Input: [1 0], Label: 1, Pred: 0.80
# Input: [1 1], Label: 0, Pred: 0.18
# Params: [0.35003474 0.98910858 0.09226055 0.1457755 ]
# Epoch 34
# Input: [0 0], Label: 0, Pred: 0.29
# Input: [0 1], Label: 1, Pred: 0.68
# Input: [1 0], Label: 1, Pred: 0.81
# Input: [1 1], Label: 0, Pred: 0.18
# Params: [0.35006892 0.98914276 0.09229473 0.14580968]
# Epoch 35
# Input: [0 0], Label: 0, Pred: 0.31
# Input: [0 1], Label: 1, Pred: 0.71
# Input: [1 0], Label: 1, Pred: 0.83
# Input: [1 1], Label: 0, Pred: 0.17
# Params: [0.35004451 0.98911835 0.09227032 0.14578526]
# Epoch 36
# Input: [0 0], Label: 0, Pred: 0.33
# Input: [0 1], Label: 1, Pred: 0.67
# Input: [1 0], Label: 1, Pred: 0.82
# Input: [1 1], Label: 0, Pred: 0.18
# Params: [0.35003376 0.9891076  0.09225957 0.14577452]
# Epoch 37
# Input: [0 0], Label: 0, Pred: 0.31
# Input: [0 1], Label: 1, Pred: 0.68
# Input: [1 0], Label: 1, Pred: 0.83
# Input: [1 1], Label: 0, Pred: 0.17
# Params: [0.35004353 0.98911737 0.09226934 0.14578429]
# Epoch 38
# Input: [0 0], Label: 0, Pred: 0.28
# Input: [0 1], Label: 1, Pred: 0.72
# Input: [1 0], Label: 1, Pred: 0.83
# Input: [1 1], Label: 0, Pred: 0.16
# Params: [0.35005037 0.9891242  0.09227617 0.14579112]
# Epoch 39
# Input: [0 0], Label: 0, Pred: 0.31
# Input: [0 1], Label: 1, Pred: 0.69
# Input: [1 0], Label: 1, Pred: 0.81
# Input: [1 1], Label: 0, Pred: 0.18
# Params: [0.35006697 0.98914081 0.09229278 0.14580773]
# Epoch 40
# Input: [0 0], Label: 0, Pred: 0.33
# Input: [0 1], Label: 1, Pred: 0.67
# Input: [1 0], Label: 1, Pred: 0.83
# Input: [1 1], Label: 0, Pred: 0.18
# Params: [0.3500572  0.98913104 0.09228301 0.14579796]
# Epoch 41
# Input: [0 0], Label: 0, Pred: 0.33
# Input: [0 1], Label: 1, Pred: 0.66
# Input: [1 0], Label: 1, Pred: 0.79
# Input: [1 1], Label: 0, Pred: 0.18
# Params: [0.35009138 0.98916522 0.09231719 0.14583214]
# Epoch 42
# Input: [0 0], Label: 0, Pred: 0.30
# Input: [0 1], Label: 1, Pred: 0.73
# Input: [1 0], Label: 1, Pred: 0.85
# Input: [1 1], Label: 0, Pred: 0.19
# Params: [0.35002009 0.98909393 0.0922459  0.14576085]
# Epoch 43
# Input: [0 0], Label: 0, Pred: 0.31
# Input: [0 1], Label: 1, Pred: 0.73
# Input: [1 0], Label: 1, Pred: 0.80
# Input: [1 1], Label: 0, Pred: 0.19
# Params: [0.34998591 0.98905975 0.09221172 0.14572667]
# Epoch 44
# Input: [0 0], Label: 0, Pred: 0.27
# Input: [0 1], Label: 1, Pred: 0.69
# Input: [1 0], Label: 1, Pred: 0.80
# Input: [1 1], Label: 0, Pred: 0.19
# Params: [0.35003865 0.98911249 0.09226446 0.1457794 ]
# Epoch 45
# Input: [0 0], Label: 0, Pred: 0.29
# Input: [0 1], Label: 1, Pred: 0.71
# Input: [1 0], Label: 1, Pred: 0.84
# Input: [1 1], Label: 0, Pred: 0.21
# Params: [0.35000154 0.98907538 0.09222735 0.1457423 ]
# Epoch 46
# Input: [0 0], Label: 0, Pred: 0.31
# Input: [0 1], Label: 1, Pred: 0.68
# Input: [1 0], Label: 1, Pred: 0.81
# Input: [1 1], Label: 0, Pred: 0.19
# Params: [0.3500074  0.98908124 0.09223321 0.14574815]
# Epoch 47
# Input: [0 0], Label: 0, Pred: 0.30
# Input: [0 1], Label: 1, Pred: 0.67
# Input: [1 0], Label: 1, Pred: 0.82
# Input: [1 1], Label: 0, Pred: 0.18
# Params: [0.35003376 0.9891076  0.09225957 0.14577452]
# Epoch 48
# Input: [0 0], Label: 0, Pred: 0.31
# Input: [0 1], Label: 1, Pred: 0.68
# Input: [1 0], Label: 1, Pred: 0.81
# Input: [1 1], Label: 0, Pred: 0.20
# Params: [0.35002888 0.98910272 0.09225469 0.14576964]
# Epoch 49
# Input: [0 0], Label: 0, Pred: 0.31
# Input: [0 1], Label: 1, Pred: 0.70
# Input: [1 0], Label: 1, Pred: 0.82
# Input: [1 1], Label: 0, Pred: 0.20
# Params: [0.35000056 0.9890744  0.09222637 0.14574132]
# Epoch 50
# Input: [0 0], Label: 0, Pred: 0.33
# Input: [0 1], Label: 1, Pred: 0.69
# Input: [1 0], Label: 1, Pred: 0.81
# Input: [1 1], Label: 0, Pred: 0.16
# Params: [0.35000544 0.98907928 0.09223125 0.1457462 ]
# Epoch 51
# Input: [0 0], Label: 0, Pred: 0.29
# Input: [0 1], Label: 1, Pred: 0.68
# Input: [1 0], Label: 1, Pred: 0.81
# Input: [1 1], Label: 0, Pred: 0.17
# Params: [0.35005818 0.98913202 0.09228399 0.14579894]
# Epoch 52
# Input: [0 0], Label: 0, Pred: 0.29
# Input: [0 1], Label: 1, Pred: 0.71
# Input: [1 0], Label: 1, Pred: 0.82
# Input: [1 1], Label: 0, Pred: 0.19
# Params: [0.35003181 0.98910565 0.09225762 0.14577257]
# Epoch 53
# Input: [0 0], Label: 0, Pred: 0.31
# Input: [0 1], Label: 1, Pred: 0.70
# Input: [1 0], Label: 1, Pred: 0.81
# Input: [1 1], Label: 0, Pred: 0.17
# Params: [0.35003865 0.98911249 0.09226446 0.1457794 ]
# Epoch 54
# Input: [0 0], Label: 0, Pred: 0.30
# Input: [0 1], Label: 1, Pred: 0.70
# Input: [1 0], Label: 1, Pred: 0.83
# Input: [1 1], Label: 0, Pred: 0.17
# Params: [0.35004548 0.98911932 0.09227129 0.14578624]
# Epoch 55
# Input: [0 0], Label: 0, Pred: 0.33
# Input: [0 1], Label: 1, Pred: 0.70
# Input: [1 0], Label: 1, Pred: 0.82
# Input: [1 1], Label: 0, Pred: 0.20
# Params: [0.34999275 0.98906659 0.09221856 0.14573351]
# Epoch 56
# Input: [0 0], Label: 0, Pred: 0.30
# Input: [0 1], Label: 1, Pred: 0.69
# Input: [1 0], Label: 1, Pred: 0.82
# Input: [1 1], Label: 0, Pred: 0.21
# Params: [0.34997126 0.9890451  0.09219707 0.14571202]
# Epoch 57
# Input: [0 0], Label: 0, Pred: 0.31
# Input: [0 1], Label: 1, Pred: 0.68
# Input: [1 0], Label: 1, Pred: 0.80
# Input: [1 1], Label: 0, Pred: 0.20
# Params: [0.3499781  0.98905194 0.09220391 0.14571886]
# Epoch 58
# Input: [0 0], Label: 0, Pred: 0.30
# Input: [0 1], Label: 1, Pred: 0.69
# Input: [1 0], Label: 1, Pred: 0.82
# Input: [1 1], Label: 0, Pred: 0.19
# Params: [0.34998103 0.98905487 0.09220684 0.14572179]
# Epoch 59
# Input: [0 0], Label: 0, Pred: 0.30
# Input: [0 1], Label: 1, Pred: 0.71
# Input: [1 0], Label: 1, Pred: 0.82
# Input: [1 1], Label: 0, Pred: 0.18
# Params: [0.34997908 0.98905292 0.09220489 0.14571983]
# Epoch 60
# Input: [0 0], Label: 0, Pred: 0.30
# Input: [0 1], Label: 1, Pred: 0.70
# Input: [1 0], Label: 1, Pred: 0.82
# Input: [1 1], Label: 0, Pred: 0.21
# Params: [0.34995173 0.98902557 0.09217754 0.14569249]
# Epoch 61
# Input: [0 0], Label: 0, Pred: 0.32
# Input: [0 1], Label: 1, Pred: 0.68
# Input: [1 0], Label: 1, Pred: 0.80
# Input: [1 1], Label: 0, Pred: 0.18
# Params: [0.34996638 0.98904022 0.09219219 0.14570714]
# Epoch 62
# Input: [0 0], Label: 0, Pred: 0.29
# Input: [0 1], Label: 1, Pred: 0.72
# Input: [1 0], Label: 1, Pred: 0.82
# Input: [1 1], Label: 0, Pred: 0.20
# Params: [0.34993806 0.9890119  0.09216387 0.14567882]
# Epoch 63
# Input: [0 0], Label: 0, Pred: 0.33
# Input: [0 1], Label: 1, Pred: 0.70
# Input: [1 0], Label: 1, Pred: 0.82
# Input: [1 1], Label: 0, Pred: 0.19
# Params: [0.34990583 0.98897967 0.09213164 0.14564659]
# Epoch 64
# Input: [0 0], Label: 0, Pred: 0.31
# Input: [0 1], Label: 1, Pred: 0.70
# Input: [1 0], Label: 1, Pred: 0.80
# Input: [1 1], Label: 0, Pred: 0.17
# Params: [0.34992537 0.9889992  0.09215117 0.14566612]
# Epoch 65
# Input: [0 0], Label: 0, Pred: 0.32
# Input: [0 1], Label: 1, Pred: 0.69
# Input: [1 0], Label: 1, Pred: 0.83
# Input: [1 1], Label: 0, Pred: 0.16
# Params: [0.34992537 0.9889992  0.09215117 0.14566612]
# Epoch 66
# Input: [0 0], Label: 0, Pred: 0.31
# Input: [0 1], Label: 1, Pred: 0.69
# Input: [1 0], Label: 1, Pred: 0.80
# Input: [1 1], Label: 0, Pred: 0.17
# Params: [0.34995759 0.98903143 0.0921834  0.14569835]
# Epoch 67
# Input: [0 0], Label: 0, Pred: 0.29
# Input: [0 1], Label: 1, Pred: 0.70
# Input: [1 0], Label: 1, Pred: 0.81
# Input: [1 1], Label: 0, Pred: 0.18
# Params: [0.34996638 0.98904022 0.09219219 0.14570714]
# Epoch 68
# Input: [0 0], Label: 0, Pred: 0.31
# Input: [0 1], Label: 1, Pred: 0.70
# Input: [1 0], Label: 1, Pred: 0.83
# Input: [1 1], Label: 0, Pred: 0.20
# Params: [0.34992146 0.9889953  0.09214727 0.14566222]
# Epoch 69
# Input: [0 0], Label: 0, Pred: 0.33
# Input: [0 1], Label: 1, Pred: 0.70
# Input: [1 0], Label: 1, Pred: 0.82
# Input: [1 1], Label: 0, Pred: 0.18
# Params: [0.34990095 0.98897479 0.09212676 0.14564171]
# Epoch 70
# Input: [0 0], Label: 0, Pred: 0.30
# Input: [0 1], Label: 1, Pred: 0.69
# Input: [1 0], Label: 1, Pred: 0.84
# Input: [1 1], Label: 0, Pred: 0.17
# Params: [0.34989802 0.98897186 0.09212383 0.14563878]
# Epoch 71
# Input: [0 0], Label: 0, Pred: 0.31
# Input: [0 1], Label: 1, Pred: 0.70
# Input: [1 0], Label: 1, Pred: 0.82
# Input: [1 1], Label: 0, Pred: 0.18
# Params: [0.34989607 0.98896991 0.09212188 0.14563683]
# Epoch 72
# Input: [0 0], Label: 0, Pred: 0.30
# Input: [0 1], Label: 1, Pred: 0.69
# Input: [1 0], Label: 1, Pred: 0.81
# Input: [1 1], Label: 0, Pred: 0.18
# Params: [0.34991169 0.98898553 0.0921375  0.14565245]
# Epoch 73
# Input: [0 0], Label: 0, Pred: 0.30
# Input: [0 1], Label: 1, Pred: 0.69
# Input: [1 0], Label: 1, Pred: 0.85
# Input: [1 1], Label: 0, Pred: 0.16
# Params: [0.34991365 0.98898749 0.09213946 0.1456544 ]
# Epoch 74
# Input: [0 0], Label: 0, Pred: 0.31
# Input: [0 1], Label: 1, Pred: 0.71
# Input: [1 0], Label: 1, Pred: 0.81
# Input: [1 1], Label: 0, Pred: 0.18
# Params: [0.3499029  0.98897674 0.09212871 0.14564366]
# Epoch 75
# Input: [0 0], Label: 0, Pred: 0.29
# Input: [0 1], Label: 1, Pred: 0.69
# Input: [1 0], Label: 1, Pred: 0.82
# Input: [1 1], Label: 0, Pred: 0.19
# Params: [0.34990193 0.98897577 0.09212774 0.14564269]
# Epoch 76
# Input: [0 0], Label: 0, Pred: 0.29
# Input: [0 1], Label: 1, Pred: 0.70
# Input: [1 0], Label: 1, Pred: 0.81
# Input: [1 1], Label: 0, Pred: 0.20
# Params: [0.34990486 0.9889787  0.09213067 0.14564562]
# Epoch 77
# Input: [0 0], Label: 0, Pred: 0.28
# Input: [0 1], Label: 1, Pred: 0.72
# Input: [1 0], Label: 1, Pred: 0.81
# Input: [1 1], Label: 0, Pred: 0.18
# Params: [0.34992048 0.98899432 0.09214629 0.14566124]
# Epoch 78
# Input: [0 0], Label: 0, Pred: 0.29
# Input: [0 1], Label: 1, Pred: 0.71
# Input: [1 0], Label: 1, Pred: 0.84
# Input: [1 1], Label: 0, Pred: 0.21
# Params: [0.3498697  0.98894354 0.09209551 0.14561046]
# Epoch 79
# Input: [0 0], Label: 0, Pred: 0.32
# Input: [0 1], Label: 1, Pred: 0.69
# Input: [1 0], Label: 1, Pred: 0.80
# Input: [1 1], Label: 0, Pred: 0.20
# Params: [0.34986482 0.98893866 0.09209063 0.14560558]
# Epoch 80
# Input: [0 0], Label: 0, Pred: 0.28
# Input: [0 1], Label: 1, Pred: 0.69
# Input: [1 0], Label: 1, Pred: 0.82
# Input: [1 1], Label: 0, Pred: 0.18
# Params: [0.349899   0.98897284 0.09212481 0.14563976]
# Epoch 81
# Input: [0 0], Label: 0, Pred: 0.29
# Input: [0 1], Label: 1, Pred: 0.70
# Input: [1 0], Label: 1, Pred: 0.80
# Input: [1 1], Label: 0, Pred: 0.21
# Params: [0.34990388 0.98897772 0.09212969 0.14564464]
# Epoch 82
# Input: [0 0], Label: 0, Pred: 0.31
# Input: [0 1], Label: 1, Pred: 0.69
# Input: [1 0], Label: 1, Pred: 0.80
# Input: [1 1], Label: 0, Pred: 0.20
# Params: [0.34990876 0.9889826  0.09213457 0.14564952]
# Epoch 83
# Input: [0 0], Label: 0, Pred: 0.31
# Input: [0 1], Label: 1, Pred: 0.70
# Input: [1 0], Label: 1, Pred: 0.83
# Input: [1 1], Label: 0, Pred: 0.17
# Params: [0.34990583 0.98897967 0.09213164 0.14564659]
# Epoch 84
# Input: [0 0], Label: 0, Pred: 0.31
# Input: [0 1], Label: 1, Pred: 0.70
# Input: [1 0], Label: 1, Pred: 0.81
# Input: [1 1], Label: 0, Pred: 0.17
# Params: [0.34991365 0.98898749 0.09213946 0.1456544 ]
# Epoch 85
# Input: [0 0], Label: 0, Pred: 0.32
# Input: [0 1], Label: 1, Pred: 0.68
# Input: [1 0], Label: 1, Pred: 0.82
# Input: [1 1], Label: 0, Pred: 0.19
# Params: [0.34990779 0.98898163 0.0921336  0.14564855]
# Epoch 86
# Input: [0 0], Label: 0, Pred: 0.33
# Input: [0 1], Label: 1, Pred: 0.69
# Input: [1 0], Label: 1, Pred: 0.81
# Input: [1 1], Label: 0, Pred: 0.16
# Params: [0.34991072 0.98898456 0.09213653 0.14565148]
# Epoch 87
# Input: [0 0], Label: 0, Pred: 0.28
# Input: [0 1], Label: 1, Pred: 0.67
# Input: [1 0], Label: 1, Pred: 0.83
# Input: [1 1], Label: 0, Pred: 0.18
# Params: [0.34994099 0.98901483 0.0921668  0.14568175]
# Epoch 88
# Input: [0 0], Label: 0, Pred: 0.31
# Input: [0 1], Label: 1, Pred: 0.69
# Input: [1 0], Label: 1, Pred: 0.82
# Input: [1 1], Label: 0, Pred: 0.20
# Params: [0.34992048 0.98899432 0.09214629 0.14566124]
# Epoch 89
# Input: [0 0], Label: 0, Pred: 0.30
# Input: [0 1], Label: 1, Pred: 0.70
# Input: [1 0], Label: 1, Pred: 0.82
# Input: [1 1], Label: 0, Pred: 0.19
# Params: [0.34991365 0.98898749 0.09213946 0.1456544 ]
# Epoch 90
# Input: [0 0], Label: 0, Pred: 0.32
# Input: [0 1], Label: 1, Pred: 0.66
# Input: [1 0], Label: 1, Pred: 0.83
# Input: [1 1], Label: 0, Pred: 0.18
# Params: [0.34993122 0.98900506 0.09215703 0.14567198]
# Epoch 91
# Input: [0 0], Label: 0, Pred: 0.30
# Input: [0 1], Label: 1, Pred: 0.69
# Input: [1 0], Label: 1, Pred: 0.82
# Input: [1 1], Label: 0, Pred: 0.18
# Params: [0.34993806 0.9890119  0.09216387 0.14567882]
# Epoch 92
# Input: [0 0], Label: 0, Pred: 0.30
# Input: [0 1], Label: 1, Pred: 0.67
# Input: [1 0], Label: 1, Pred: 0.82
# Input: [1 1], Label: 0, Pred: 0.18
# Params: [0.34996736 0.9890412  0.09219317 0.14570812]
# Epoch 93
# Input: [0 0], Label: 0, Pred: 0.32
# Input: [0 1], Label: 1, Pred: 0.69
# Input: [1 0], Label: 1, Pred: 0.81
# Input: [1 1], Label: 0, Pred: 0.20
# Params: [0.34994294 0.98901678 0.09216875 0.1456837 ]
# Epoch 94
# Input: [0 0], Label: 0, Pred: 0.31
# Input: [0 1], Label: 1, Pred: 0.71
# Input: [1 0], Label: 1, Pred: 0.82
# Input: [1 1], Label: 0, Pred: 0.17
# Params: [0.34993904 0.98901288 0.09216485 0.1456798 ]
# Epoch 95
# Input: [0 0], Label: 0, Pred: 0.33
# Input: [0 1], Label: 1, Pred: 0.71
# Input: [1 0], Label: 1, Pred: 0.83
# Input: [1 1], Label: 0, Pred: 0.19
# Params: [0.34987849 0.98895233 0.0921043  0.14561925]
# Epoch 96
# Input: [0 0], Label: 0, Pred: 0.32
# Input: [0 1], Label: 1, Pred: 0.74
# Input: [1 0], Label: 1, Pred: 0.79
# Input: [1 1], Label: 0, Pred: 0.20
# Params: [0.34983943 0.98891327 0.09206524 0.14558019]
# Epoch 97
# Input: [0 0], Label: 0, Pred: 0.29
# Input: [0 1], Label: 1, Pred: 0.71
# Input: [1 0], Label: 1, Pred: 0.81
# Input: [1 1], Label: 0, Pred: 0.19
# Params: [0.34983552 0.98890936 0.09206133 0.14557628]
# Epoch 98
# Input: [0 0], Label: 0, Pred: 0.31
# Input: [0 1], Label: 1, Pred: 0.72
# Input: [1 0], Label: 1, Pred: 0.80
# Input: [1 1], Label: 0, Pred: 0.19
# Params: [0.34981111 0.98888495 0.09203692 0.14555187]
# Epoch 99
# Input: [0 0], Label: 0, Pred: 0.31
# Input: [0 1], Label: 1, Pred: 0.68
# Input: [1 0], Label: 1, Pred: 0.80
# Input: [1 1], Label: 0, Pred: 0.19
# Params: [0.34983064 0.98890448 0.09205645 0.1455714 ]
# Epoch 100
# Input: [0 0], Label: 0, Pred: 0.30
# Input: [0 1], Label: 1, Pred: 0.68
# Input: [1 0], Label: 1, Pred: 0.82
# Input: [1 1], Label: 0, Pred: 0.20
# Params: [0.34983064 0.98890448 0.09205645 0.1455714 ]
